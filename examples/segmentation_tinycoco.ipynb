# %%
from data_gradients.managers.segmentation_manager import SegmentationAnalysisManager
from data_gradients.datasets.segmentation.coco_segmentation_dataset import CocoSegmentationDataset

# %%
train_set = CocoSegmentationDataset(
    root_dir="../example_dataset/tinycoco",
    split="train",
    year="2017",
)
val_set = CocoSegmentationDataset(
    root_dir="../example_dataset/tinycoco",
    split="val",
    year="2017",
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
manager = SegmentationAnalysisManager(
    report_title="Testing Data-Gradients NEW",
    train_data=train_set,
    val_data=train_set,
    class_names=train_set.class_names,
)
# Out:
# INFO:data_gradients.utils.summary_writer:`log_dir` was not set, so the logs will be saved in /Users/Louis.Dupont/PycharmProjects/data-gradients/examples/logs/Testing_Data-Gradients_NEW
# INFO:data_gradients.config.data.data_config:Cache deactivated for `SegmentationDataConfig`. Please set `load_cache=True` if you want to activate it.

# %%
manager.run()
# Out:
#   - Executing analysis with:
#   - batches_early_stop: None
#   - len(train_data): 32
#   - len(val_data): 32
#   - log directory: /Users/Louis.Dupont/PycharmProjects/data-gradients/examples/logs/Testing_Data-Gradients_NEW
#   - Archive directory: /Users/Louis.Dupont/PycharmProjects/data-gradients/examples/logs/Testing_Data-Gradients_NEW/archive_20230719-170719
#   - feature extractor list: {'Image Features': [SummaryStats, ImagesResolution, ImageColorDistribution, ImagesAverageBrightness], 'Segmentation Features': [SegmentationSampleVisualization, SegmentationClassHeatmap, SegmentationClassFrequency, SegmentationClassesPerImageCount, SegmentationComponentsPerImageCount, SegmentationBoundingBoxResolution, SegmentationBoundingBoxArea, SegmentationComponentsConvexity, SegmentationComponentsErosion]}
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║  To better understand how to tackle the data issues highlighted in this  ║
# ...
