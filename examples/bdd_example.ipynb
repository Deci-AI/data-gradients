# %% [markdown]
# # BDD-100K dataset analysis
#
# This notebook demonstrate how to apply Data Gradients to extract insights from BDD-100K dataset
#
# We start by importing data-set adapters for BDD100K:

# %%
from data_gradients.dataset_adapters import BDD100KSegmentationDatasetAdapter

train_dataset = BDD100KSegmentationDatasetAdapter(
    data_dir="../src/data_gradients/example_dataset/bdd_example/train",
)
val_dataset = BDD100KSegmentationDatasetAdapter(
    data_dir="../src/data_gradients/example_dataset/bdd_example/val",
)

dataset = {
    "train": train_dataset,
    "val": val_dataset,
}

# %% [markdown]
# # Single-line example

# %%
from data_gradients.managers.segmentation_manager import SegmentationAnalysisManager

SegmentationAnalysisManager.plot_analysis(dataset)
# Out:
# ...
# Extracting features: 100%|██████████| 10/10 [00:04<00:00,  2.48it/s]
